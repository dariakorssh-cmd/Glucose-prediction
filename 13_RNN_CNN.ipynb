# %% [markdown]
# <a href="https://colab.research.google.com/github/dariakorssh-cmd/Korshekova-640-01/blob/main/13_RNN_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
assert sys.version_info >= (3, 10)
import torch
import torch.nn as nn
torch.manual_seed(42)

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.9.0+cu126)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 21.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.15.2 torchmetrics-1.8.2

# %%
import torchmetrics
import torch
from packaging.version import Version

assert Version(torch.__version__) >= Version("2.8.0")

# %%
if torch.cuda.is_available():
    device = "cuda"
if torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"
device
# Out:
# 'cpu'

# %% [markdown]
# # Прогнозирование временного ряда

# %%
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request

def download_and_extract_ridership_data():
    tarball_path = Path("datasets/ridership.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/AlexeyTri/PyTorchTutorials_2025/blob/main/data/ridership.tgz"
        urllib.request.urlretrieve(url, tarball_path)
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets", filter="data")

download_and_extract_ridership_data()

# %%
import pandas as pd
from pathlib import Path

path = Path("datasets/ridership/CTA_-_Ridership_-_Daily_Boarding_Totals.csv")
df = pd.read_csv(path, parse_dates=["service_date"])
df.columns = ["date", "day_type", "bus", "rail", "total"]  # shorter names
df = df.sort_values("date").set_index("date")
df = df.drop("total", axis=1)  # no need for total, it's just bus + rail
df = df.drop_duplicates()  # remove duplicated months (2011-10 and 2014-07)

# %%
df.head()
# Out:
#            day_type     bus    rail
# date
# 2001-01-01        U  297192  126455
# 2001-01-02        W  780827  501952
# 2001-01-03        W  824923  536432
# 2001-01-04        W  870021  550011
# 2001-01-05        W  890426  557917

# %%
import matplotlib.pyplot as plt

df["2019-03":"2019-05"].plot(grid=True, marker=".", figsize=(10, 3.5))
plt.show()

# %% [markdown]
# **Задание №1:** построить наивное предсказание, для одного месяца(май 2019) поездок на АВТОБУСЕ, взяв за основу годовой временной промежуток
#
# 1 балл

# %%
diff_7 = df[["bus", "rail"]].diff(7)["2019-03":"2019-05"]

fig, axs = plt.subplots(2, 1, sharex=True, figsize=(8, 5))
df.plot(ax=axs[0], legend=False, marker=".")  # original time series
df.shift(7).plot(ax=axs[0], grid=True, legend=False, linestyle=":")  # lagged
diff_7.plot(ax=axs[1], grid=True, marker=".")  # 7-day difference time series
axs[0].set_ylim([170_000, 900_000])  # extra code – beautifies the plot

plt.show()

# %%
[(df.loc["2019-05-25":"2019-05-27"]["day_type"])]
# Out:
# [date
#  2019-05-25    A
#  2019-05-26    U
#  2019-05-27    U
#  Name: day_type, dtype: object]

# %%
# MAE
diff_7.abs().mean()
# Out:
# bus     43915.608696
# rail    42143.271739
# dtype: float64

# %%
# MAPE
targets = df[["bus", "rail"]]["2019-03":"2019-05"]
(diff_7 / targets).abs().mean()
# Out:
# bus     0.082938
# rail    0.089948
# dtype: float64

# %%
period = slice("2001", "2019")
df_monthly = df.select_dtypes(include="number").resample("ME").mean()
rolling_average_12_months = df_monthly.loc[period].rolling(window=12).mean()

fig, ax = plt.subplots(figsize=(8, 4))
df_monthly[period].plot(ax=ax, marker=".")
rolling_average_12_months.plot(ax=ax, grid=True, legend=False)
plt.show()

# %%
df_monthly.diff(12)[period].plot(grid=True, marker=".", figsize=(8, 3))
plt.show()

# %% [markdown]
# **ARMA**

# %% [markdown]
# **Задание №2:** построить предсказание при помощи модели ARIMA, для одного месяца(май 2019) поездок на АВТОБУСЕ, взяв за основу годовой временной промежуток.
# Применить оба варианта использования модели ARIMA
#
# Вариант №1 - 1 балл
#
# Вариант №2 - 1 балл

# %%
# !pip install statsmodels
import statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
from statsmodels.tsa.arima.model import ARIMA

origin, today = "2019-01-01", "2019-05-31"
rail_series = df.loc[origin:today]["rail"].asfreq("D")

model = ARIMA(rail_series,
              order=(1, 0, 0), # p=1, d=0, q=0
              seasonal_order=(0, 1, 1, 7)) # p=0, d=1, q=1, s=7

model = model.fit()

y_pred = model.forecast()
y_pred.item() - df.loc["2019-06-01"]["rail"].item()
# Out:
# 48714.62642106105

# %%
origin, start_date, end_date = "2019-01-01", "2019-03-01", "2019-05-31"
time_period = pd.date_range(start_date, end_date)
rail_series = df.loc[origin:end_date]["rail"].asfreq("D")
y_preds = []
for today in time_period.shift(-1):
    model = ARIMA(rail_series[origin:today],
                  order=(1,0,0),
                  seasonal_order=(0, 1, 1, 7))
    model = model.fit()
    y_pred = model.forecast().iloc[0]
    y_preds.append(y_pred)

y_preds = pd.Series(y_preds, index=time_period)
mae = (y_preds - rail_series[time_period]).abs().mean()
mae.item()
# Out:
# 32040.720094289627

# %%
fig, ax = plt.subplots(figsize=(8, 3))
rail_series.loc[time_period].plot(label="True", ax=ax, marker=".", grid=True)
ax.plot(y_preds, color="r", marker=".", label="SARIMA Forecasts")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-2360366094.py:3: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   ax.plot(y_preds, color="r", marker=".", label="SARIMA Forecasts")

# %% [markdown]
# **Подготовка данных**

# %%
class TimeSeriesDataset(torch.utils.data.Dataset):
    def __init__(self, series, window_length):
        self.series = series
        self.window_length = window_length

    def __len__(self):
        return (len(self.series) - self.window_length)

    def __getitem__(self, idx):
        if idx >= len(self):
            raise IndexError("dataset index out of range")
        end = idx + self.window_length
        window = self.series[idx:end]
        target = self.series[end]
        return window, target

# %%
my_series = torch.tensor([[0], [1], [2], [3], [4], [5], [6], [7]])
time_series = TimeSeriesDataset(my_series, 3)
for window, target in time_series:
    print(f"window: {window}, target: {target}")
# Out:
# window: tensor([[0],
#         [1],
#         [2]]), target: tensor([3])
# window: tensor([[1],
#         [2],
#         [3]]), target: tensor([4])
# window: tensor([[2],
#         [3],
#         [4]]), target: tensor([5])
# window: tensor([[3],
#         [4],
#         [5]]), target: tensor([6])
# window: tensor([[4],
#         [5],
#         [6]]), target: tensor([7])

# %%
from torch.utils.data import DataLoader

torch.manual_seed(0)
my_loader = DataLoader(time_series, batch_size=2, shuffle=True)
for X, y in my_loader:
    print(f"X: {X}, y: {y}")
# Out:
# X: tensor([[[1],
#          [2],
#          [3]],
#
#         [[4],
#          [5],
#          [6]]]), y: tensor([[4],
#         [7]])
# X: tensor([[[2],
#          [3],
#          [4]],
#
#         [[3],
#          [4],
#          [5]]]), y: tensor([[5],
#         [6]])
# X: tensor([[[0],
#          [1],
#          [2]]]), y: tensor([[3]])

# %%
rail_train = torch.FloatTensor(df[["rail"]]["2016-01":"2018-12"].values / 1e6)
rail_valid = torch.FloatTensor(df[["rail"]]["2019-01":"2019-05"].values / 1e6)
rail_test = torch.FloatTensor(df[["rail"]]["2019-06":].values / 1e6)

# %%
window_length = 56
train_set = TimeSeriesDataset(rail_train, window_length)
train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
valid_set = TimeSeriesDataset(rail_valid, window_length)
valid_loader = DataLoader(valid_set, batch_size=32)
test_set = TimeSeriesDataset(rail_test, window_length)
test_loader = DataLoader(test_set, batch_size=32)

# %%
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (1.8.2)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.8.0+cu126)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (0.15.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)

# %%
import torchmetrics

def evaluate_tm(model, data_loader, metric):
    model.eval()
    metric.reset()
    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            metric.update(y_pred, y_batch)
    return metric.compute()

# %%
def train(model, optimizer, loss_fn, metric, train_loader, valid_loader,
          n_epochs, patience=10, factor=0.1):
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", patience=patience, factor=factor)
    history = {"train_losses": [], "train_metrics": [], "valid_metrics": []}
    for epoch in range(n_epochs):
        total_loss = 0.0
        metric.reset()
        model.train()
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            total_loss += loss.item()
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            metric.update(y_pred, y_batch)
        history["train_losses"].append(total_loss / len(train_loader))
        history["train_metrics"].append(metric.compute().item())
        val_metric = evaluate_tm(model, valid_loader, metric).item()
        history["valid_metrics"].append(val_metric)
        scheduler.step(val_metric)
        print(f"Epoch {epoch + 1}/{n_epochs}, "
              f"train loss: {history['train_losses'][-1]:.4f}, "
              f"train metric: {history['train_metrics'][-1]:.4f}, "
              f"valid metric: {history['valid_metrics'][-1]:.4f}")
    return history

# %%
model = nn.Sequential(nn.Flatten(), nn.Linear(window_length, 1)).to(device)
loss_fn = nn.HuberLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.003, momentum=0.9)
metric = torchmetrics.MeanAbsoluteError().to(device)

history = train(model, optimizer, loss_fn, metric, train_loader,
                valid_loader, n_epochs=50)
# Out:
# Epoch 1/50, train loss: 0.0689, train metric: 0.2903, valid metric: 0.1464
# Epoch 2/50, train loss: 0.0125, train metric: 0.1230, valid metric: 0.1031
# Epoch 3/50, train loss: 0.0082, train metric: 0.0966, valid metric: 0.0762
# Epoch 4/50, train loss: 0.0066, train metric: 0.0834, valid metric: 0.0702
# Epoch 5/50, train loss: 0.0062, train metric: 0.0779, valid metric: 0.0668
# Epoch 6/50, train loss: 0.0058, train metric: 0.0750, valid metric: 0.0658
# Epoch 7/50, train loss: 0.0055, train metric: 0.0726, valid metric: 0.0631
# Epoch 8/50, train loss: 0.0054, train metric: 0.0725, valid metric: 0.0595
# Epoch 9/50, train loss: 0.0051, train metric: 0.0695, valid metric: 0.0598
# Epoch 10/50, train loss: 0.0051, train metric: 0.0680, valid metric: 0.0619
# Epoch 11/50, train loss: 0.0050, train metric: 0.0690, valid metric: 0.0585
# Epoch 12/50, train loss: 0.0049, train metric: 0.0666, valid metric: 0.0579
# Epoch 13/50, train loss: 0.0047, train metric: 0.0655, valid metric: 0.0584
# Epoch 14/50, train loss: 0.0047, train metric: 0.0653, valid metric: 0.0571
# Epoch 15/50, train loss: 0.0046, train metric: 0.0649, valid metric: 0.0553
# Epoch 16/50, train loss: 0.0046, train metric: 0.0644, valid metric: 0.0594
# Epoch 17/50, train loss: 0.0046, train metric: 0.0633, valid metric: 0.0555
# Epoch 18/50, train loss: 0.0044, train metric: 0.0628, valid metric: 0.0536
# Epoch 19/50, train loss: 0.0044, train metric: 0.0626, valid metric: 0.0534
# Epoch 20/50, train loss: 0.0044, train metric: 0.0622, valid metric: 0.0525
# Epoch 21/50, train loss: 0.0044, train metric: 0.0615, valid metric: 0.0524
# Epoch 22/50, train loss: 0.0043, train metric: 0.0615, valid metric: 0.0529
# Epoch 23/50, train loss: 0.0042, train metric: 0.0604, valid metric: 0.0528
# Epoch 24/50, train loss: 0.0042, train metric: 0.0604, valid metric: 0.0519
# Epoch 25/50, train loss: 0.0042, train metric: 0.0610, valid metric: 0.0522
# Epoch 26/50, train loss: 0.0041, train metric: 0.0596, valid metric: 0.0504
# Epoch 27/50, train loss: 0.0041, train metric: 0.0594, valid metric: 0.0501
# Epoch 28/50, train loss: 0.0041, train metric: 0.0593, valid metric: 0.0523
# Epoch 29/50, train loss: 0.0040, train metric: 0.0591, valid metric: 0.0497
# Epoch 30/50, train loss: 0.0040, train metric: 0.0584, valid metric: 0.0498
# Epoch 31/50, train loss: 0.0039, train metric: 0.0576, valid metric: 0.0494
# Epoch 32/50, train loss: 0.0039, train metric: 0.0574, valid metric: 0.0498
# Epoch 33/50, train loss: 0.0039, train metric: 0.0573, valid metric: 0.0485
# Epoch 34/50, train loss: 0.0040, train metric: 0.0569, valid metric: 0.0486
# Epoch 35/50, train loss: 0.0040, train metric: 0.0563, valid metric: 0.0483
# Epoch 36/50, train loss: 0.0038, train metric: 0.0561, valid metric: 0.0517
# Epoch 37/50, train loss: 0.0038, train metric: 0.0568, valid metric: 0.0477
# Epoch 38/50, train loss: 0.0038, train metric: 0.0557, valid metric: 0.0517
# Epoch 39/50, train loss: 0.0037, train metric: 0.0557, valid metric: 0.0484
# Epoch 40/50, train loss: 0.0037, train metric: 0.0553, valid metric: 0.0470
# Epoch 41/50, train loss: 0.0036, train metric: 0.0552, valid metric: 0.0464
# Epoch 42/50, train loss: 0.0036, train metric: 0.0546, valid metric: 0.0489
# Epoch 43/50, train loss: 0.0036, train metric: 0.0556, valid metric: 0.0484
# Epoch 44/50, train loss: 0.0036, train metric: 0.0543, valid metric: 0.0466
# Epoch 45/50, train loss: 0.0036, train metric: 0.0542, valid metric: 0.0465
# Epoch 46/50, train loss: 0.0035, train metric: 0.0539, valid metric: 0.0464
# Epoch 47/50, train loss: 0.0035, train metric: 0.0535, valid metric: 0.0455
# Epoch 48/50, train loss: 0.0037, train metric: 0.0538, valid metric: 0.0473
# Epoch 49/50, train loss: 0.0035, train metric: 0.0536, valid metric: 0.0459
# Epoch 50/50, train loss: 0.0034, train metric: 0.0533, valid metric: 0.0450

# %%
evaluate_tm(model, valid_loader, metric).item() * 1e6
# Out:
# 45045.53973674774

# %% [markdown]
# # Simple RNN

# %% [markdown]
# ![hmls_1310.png](data:image/png;base64,...)

# %% [markdown]
# **Задание №3:** обучить модели и дать предсказание для месмячного пассажиропотока поездок на АВТОБСУЕ для моделей:
#
# 1. SimpleRnnWithLN - 2 балла
#
# 2. LSTM - 2 балла
#
# 3. GruModel - 2 балла
#
# 4. WavenetModel - 2 балла
#
# 5. Построить единый график метрик качества каждой модели, на основании данного графика сделать вывод, какая модель наиболее подходит для решения данной задачи - 2 балл

# %%
class SimleRnnWithLN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.memmory_cell = nn.Sequential(nn.Linear(input_size + hidden_size, hidden_size), nn.Tanh())
        self.output = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        batch_size, window_length, dimetionaly = X.shape
        X_time_first = X.transpose(0, 1)
        H = torch.zeros(batch_size, self.hidden_size, device=X.device)
        for X_t in X_time_first:
            XH = torch.cat((X_t, H), dim=1)
            H = self.memmory_cell(XH)
        return self.output(H)

# %%
class LstmModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.output = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        outputs, (hidden, cell) = self.lstm(X)
        return self.output(outputs[:, -1, :])

# %%
univar_model = SimleRnnModel(input_size=1, hidden_size=32, output_size=1)

# %%
def fit_and_evaluate(model, train_loader, valid_loader, lr, n_epochs=50, patience=20, factor=0.1):
    loss_fn = nn.HuberLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    metric = torchmetrics.MeanAbsoluteError().to(device)

    history = train(model, optimizer=optimizer, loss_fn=loss_fn, metric=metric, train_loader=train_loader, valid_loader=valid_loader, n_epochs=n_epochs, patience=patience, factor=factor)

    return min(history["valid_metrics"]) * 1e6

# %%
univar_model = SimpleRNNModel(input_size=1, hidden_size=32, output_size=1)
univar_model = univar_model.to(device)
fit_and_evaluate(model=univar_model, train_loader=train_loader, valid_loader=valid_loader, lr=0.05)
# Out:
# Epoch 1/50, train loss: 0.0426, train metric: 0.2302, valid metric: 0.1781
# Epoch 2/50, train loss: 0.0154, train metric: 0.1470, valid metric: 0.1194
# Epoch 3/50, train loss: 0.0132, train metric: 0.1438, valid metric: 0.1245
# Epoch 4/50, train loss: 0.0122, train metric: 0.1351, valid metric: 0.1146
# Epoch 5/50, train loss: 0.0114, train metric: 0.1282, valid metric: 0.1181
# Epoch 6/50, train loss: 0.0106, train metric: 0.1231, valid metric: 0.1117
# Epoch 7/50, train loss: 0.0098, train metric: 0.1166, valid metric: 0.1038
# Epoch 8/50, train loss: 0.0087, train metric: 0.1060, valid metric: 0.1118
# Epoch 9/50, train loss: 0.0075, train metric: 0.0965, valid metric: 0.0966
# Epoch 10/50, train loss: 0.0066, train metric: 0.0880, valid metric: 0.0865
# Epoch 11/50, train loss: 0.0057, train metric: 0.0809, valid metric: 0.0706
# Epoch 12/50, train loss: 0.0054, train metric: 0.0766, valid metric: 0.0664
# Epoch 13/50, train loss: 0.0051, train metric: 0.0746, valid metric: 0.0686
# Epoch 14/50, train loss: 0.0047, train metric: 0.0711, valid metric: 0.0676
# Epoch 15/50, train loss: 0.0046, train metric: 0.0702, valid metric: 0.0604
# Epoch 16/50, train loss: 0.0045, train metric: 0.0682, valid metric: 0.0660
# Epoch 17/50, train loss: 0.0047, train metric: 0.0684, valid metric: 0.0650
# Epoch 18/50, train loss: 0.0043, train metric: 0.0666, valid metric: 0.0610
# Epoch 19/50, train loss: 0.0043, train metric: 0.0660, valid metric: 0.0592
# Epoch 20/50, train loss: 0.0041, train metric: 0.0653, valid metric: 0.0608
# Epoch 21/50, train loss: 0.0040, train metric: 0.0627, valid metric: 0.0624
# Epoch 22/50, train loss: 0.0041, train metric: 0.0645, valid metric: 0.0574
# Epoch 23/50, train loss: 0.0040, train metric: 0.0625, valid metric: 0.0638
# Epoch 24/50, train loss: 0.0041, train metric: 0.0639, valid metric: 0.0600
# Epoch 25/50, train loss: 0.0040, train metric: 0.0639, valid metric: 0.0590
# Epoch 26/50, train loss: 0.0038, train metric: 0.0610, valid metric: 0.0554
# Epoch 27/50, train loss: 0.0035, train metric: 0.0575, valid metric: 0.0519
# Epoch 28/50, train loss: 0.0035, train metric: 0.0576, valid metric: 0.0562
# Epoch 29/50, train loss: 0.0033, train metric: 0.0544, valid metric: 0.0493
# Epoch 30/50, train loss: 0.0034, train metric: 0.0557, valid metric: 0.0505
# Epoch 31/50, train loss: 0.0033, train metric: 0.0533, valid metric: 0.0510
# Epoch 32/50, train loss: 0.0031, train metric: 0.0509, valid metric: 0.0448
# Epoch 33/50, train loss: 0.0029, train metric: 0.0477, valid metric: 0.0441
# Epoch 34/50, train loss: 0.0028, train metric: 0.0478, valid metric: 0.0447
# Epoch 35/50, train loss: 0.0027, train metric: 0.0433, valid metric: 0.0433
# Epoch 36/50, train loss: 0.0027, train metric: 0.0448, valid metric: 0.0373
# Epoch 37/50, train loss: 0.0026, train metric: 0.0426, valid metric: 0.0389
# Epoch 38/50, train loss: 0.0027, train metric: 0.0452, valid metric: 0.0418
# Epoch 39/50, train loss: 0.0026, train metric: 0.0414, valid metric: 0.0343
# Epoch 40/50, train loss: 0.0026, train metric: 0.0435, valid metric: 0.0341
# Epoch 41/50, train loss: 0.0025, train metric: 0.0408, valid metric: 0.0373
# Epoch 42/50, train loss: 0.0027, train metric: 0.0440, valid metric: 0.0453
# Epoch 43/50, train loss: 0.0026, train metric: 0.0444, valid metric: 0.0343
# Epoch 44/50, train loss: 0.0026, train metric: 0.0432, valid metric: 0.0354
# Epoch 45/50, train loss: 0.0026, train metric: 0.0425, valid metric: 0.0405
# Epoch 46/50, train loss: 0.0026, train metric: 0.0435, valid metric: 0.0324
# Epoch 47/50, train loss: 0.0026, train metric: 0.0425, valid metric: 0.0366
# Epoch 48/50, train loss: 0.0025, train metric: 0.0414, valid metric: 0.0351
# Epoch 49/50, train loss: 0.0025, train metric: 0.0401, valid metric: 0.0355
# Epoch 50/50, train loss: 0.0026, train metric: 0.0435, valid metric: 0.0308
# 30768.657103180885

# %%
class DeepRnnModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super().__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers=num_layers, batch_first=True)
        self.output = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        outputs, last_state = self.rnn(X)
        return self.output(outputs[:, -1])

# %%
deep_model = DeepRnnModel(input_size=1, hidden_size=32, output_size=1, num_layers=3).to(device)
fit_and_evaluate(model=deep_model, train_loader=train_loader, valid_loader=valid_loader, lr=0.07, n_epochs=50)
# Out:
# Epoch 1/50, train loss: 0.0437, train metric: 0.2295, valid metric: 0.1578
# Epoch 2/50, train loss: 0.0167, train metric: 0.1589, valid metric: 0.1285
# Epoch 3/50, train loss: 0.0155, train metric: 0.1553, valid metric: 0.1229
# Epoch 4/50, train loss: 0.0134, train metric: 0.1414, valid metric: 0.0973
# Epoch 5/50, train loss: 0.0095, train metric: 0.1073, valid metric: 0.1159
# Epoch 6/50, train loss: 0.0083, train metric: 0.0995, valid metric: 0.0878
# Epoch 7/50, train loss: 0.0074, train metric: 0.0937, valid metric: 0.0812
# Epoch 8/50, train loss: 0.0067, train metric: 0.0871, valid metric: 0.0797
# Epoch 9/50, train loss: 0.0061, train metric: 0.0813, valid metric: 0.0731
# Epoch 10/50, train loss: 0.0051, train metric: 0.0732, valid metric: 0.0629
# Epoch 11/50, train loss: 0.0047, train metric: 0.0679, valid metric: 0.0543
# Epoch 12/50, train loss: 0.0045, train metric: 0.0662, valid metric: 0.0513
# Epoch 13/50, train loss: 0.0045, train metric: 0.0649, valid metric: 0.0541
# Epoch 14/50, train loss: 0.0042, train metric: 0.0620, valid metric: 0.0552
# Epoch 15/50, train loss: 0.0040, train metric: 0.0599, valid metric: 0.0560
# Epoch 16/50, train loss: 0.0040, train metric: 0.0604, valid metric: 0.0592
# Epoch 17/50, train loss: 0.0039, train metric: 0.0612, valid metric: 0.0475
# Epoch 18/50, train loss: 0.0034, train metric: 0.0548, valid metric: 0.0430
# Epoch 19/50, train loss: 0.0033, train metric: 0.0526, valid metric: 0.0547
# Epoch 20/50, train loss: 0.0037, train metric: 0.0582, valid metric: 0.0390
# Epoch 21/50, train loss: 0.0031, train metric: 0.0496, valid metric: 0.0350
# Epoch 22/50, train loss: 0.0030, train metric: 0.0489, valid metric: 0.0441
# Epoch 23/50, train loss: 0.0029, train metric: 0.0474, valid metric: 0.0436
# Epoch 24/50, train loss: 0.0033, train metric: 0.0536, valid metric: 0.0365
# Epoch 25/50, train loss: 0.0031, train metric: 0.0522, valid metric: 0.0368
# Epoch 26/50, train loss: 0.0031, train metric: 0.0507, valid metric: 0.0365
# Epoch 27/50, train loss: 0.0029, train metric: 0.0479, valid metric: 0.0443
# Epoch 28/50, train loss: 0.0032, train metric: 0.0514, valid metric: 0.0452
# Epoch 29/50, train loss: 0.0030, train metric: 0.0503, valid metric: 0.0452
# Epoch 30/50, train loss: 0.0031, train metric: 0.0512, valid metric: 0.0394
# Epoch 31/50, train loss: 0.0028, train metric: 0.0460, valid metric: 0.0338
# Epoch 32/50, train loss: 0.0032, train metric: 0.0507, valid metric: 0.0459
# Epoch 33/50, train loss: 0.0030, train metric: 0.0511, valid metric: 0.0369
# Epoch 34/50, train loss: 0.0027, train metric: 0.0449, valid metric: 0.0427
# Epoch 35/50, train loss: 0.0028, train metric: 0.0475, valid metric: 0.0383
# Epoch 36/50, train loss: 0.0027, train metric: 0.0435, valid metric: 0.0334
# Epoch 37/50, train loss: 0.0027, train metric: 0.0440, valid metric: 0.0443
# Epoch 38/50, train loss: 0.0027, train metric: 0.0449, valid metric: 0.0374
# Epoch 39/50, train loss: 0.0026, train metric: 0.0436, valid metric: 0.0345
# Epoch 40/50, train loss: 0.0028, train metric: 0.0472, valid metric: 0.0357
# Epoch 41/50, train loss: 0.0029, train metric: 0.0469, valid metric: 0.0398
# Epoch 42/50, train loss: 0.0027, train metric: 0.0445, valid metric: 0.0364
# Epoch 43/50, train loss: 0.0028, train metric: 0.0438, valid metric: 0.0545
# Epoch 44/50, train loss: 0.0026, train metric: 0.0451, valid metric: 0.0316
# Epoch 45/50, train loss: 0.0027, train metric: 0.0440, valid metric: 0.0340
# Epoch 46/50, train loss: 0.0030, train metric: 0.0497, valid metric: 0.0440
# Epoch 47/50, train loss: 0.0028, train metric: 0.0466, valid metric: 0.0357
# Epoch 48/50, train loss: 0.0026, train metric: 0.0417, valid metric: 0.0399
# Epoch 49/50, train loss: 0.0027, train metric: 0.0463, valid metric: 0.0351
# Epoch 50/50, train loss: 0.0027, train metric: 0.0444, valid metric: 0.0407
# 31595.78889608383

# %% [markdown]
# **Multivariate time series**

# %%
df_mulvar = df[["rail", "bus"]] / 1e6
df_mulvar["next_day_type"] = df["day_type"].shift(-1)
df_mulvar = pd.get_dummies(df_mulvar, dtype=float)

# %%
mulvar_train = torch.FloatTensor(df_mulvar["2016-01":"2018-12"].values)
mulvar_test = torch.FloatTensor(df_mulvar["2019-06":].values)
mulvar_valid = torch.FloatTensor(df_mulvar["2019-01":"2019-05"].values)

# %%
class MultiTimeSeries(TimeSeriesDataset):
    def __getitem__(self, idx):
        window, target = super().__getitem__(idx)
        return window, target[:2]

# %%
window_length = 56
multivar_train_set = MultiTimeSeries(mulvar_train, window_length)
multivar_train_loader = DataLoader(multivar_train_set, batch_size=32, shuffle=True)
multivar_test_set = MultiTimeSeries(mulvar_test, window_length)
multivar_test_loader = DataLoader(mulvar_test, batch_size=32)
multivar_val_set = MultiTimeSeries(mulvar_valid, window_length)
multivar_valid_loader = DataLoader(multivar_val_set, batch_size=32)

# %%
mulvar_model = SimpleRNNModel(input_size=5, hidden_size=32, output_size=2)
mulvar_model = mulvar_model.to(device)

# %%
fit_and_evaluate(model=mulvar_model, train_loader=multivar_train_loader, valid_loader=multivar_valid_loader, lr=0.03, n_epochs=50)
# Out:
# Epoch 1/50, train loss: 0.0589, train metric: 0.2398, valid metric: 0.0915
# Epoch 2/50, train loss: 0.0032, train metric: 0.0595, valid metric: 0.0419
# Epoch 3/50, train loss: 0.0021, train metric: 0.0447, valid metric: 0.0340
# Epoch 4/50, train loss: 0.0020, train metric: 0.0432, valid metric: 0.0405
# Epoch 5/50, train loss: 0.0019, train metric: 0.0420, valid metric: 0.0354
# Epoch 6/50, train loss: 0.0018, train metric: 0.0411, valid metric: 0.0354
# Epoch 7/50, train loss: 0.0017, train metric: 0.0408, valid metric: 0.0343
# Epoch 8/50, train loss: 0.0017, train metric: 0.0406, valid metric: 0.0397
# Epoch 9/50, train loss: 0.0017, train metric: 0.0399, valid metric: 0.0329
# Epoch 10/50, train loss: 0.0017, train metric: 0.0394, valid metric: 0.0296
# Epoch 11/50, train loss: 0.0016, train metric: 0.0400, valid metric: 0.0322
# Epoch 12/50, train loss: 0.0016, train metric: 0.0395, valid metric: 0.0404
# Epoch 13/50, train loss: 0.0016, train metric: 0.0395, valid metric: 0.0330
# Epoch 14/50, train loss: 0.0015, train metric: 0.0384, valid metric: 0.0355
# Epoch 15/50, train loss: 0.0015, train metric: 0.0376, valid metric: 0.0278
# Epoch 16/50, train loss: 0.0015, train metric: 0.0376, valid metric: 0.0272
# Epoch 17/50, train loss: 0.0014, train metric: 0.0375, valid metric: 0.0361
# Epoch 18/50, train loss: 0.0014, train metric: 0.0370, valid metric: 0.0318
# Epoch 19/50, train loss: 0.0014, train metric: 0.0370, valid metric: 0.0349
# Epoch 20/50, train loss: 0.0014, train metric: 0.0366, valid metric: 0.0266
# Epoch 21/50, train loss: 0.0014, train metric: 0.0375, valid metric: 0.0277
# Epoch 22/50, train loss: 0.0014, train metric: 0.0363, valid metric: 0.0295
# Epoch 23/50, train loss: 0.0013, train metric: 0.0360, valid metric: 0.0301
# Epoch 24/50, train loss: 0.0013, train metric: 0.0358, valid metric: 0.0287
# Epoch 25/50, train loss: 0.0013, train metric: 0.0356, valid metric: 0.0326
# Epoch 26/50, train loss: 0.0013, train metric: 0.0359, valid metric: 0.0273
# Epoch 27/50, train loss: 0.0013, train metric: 0.0352, valid metric: 0.0265
# Epoch 28/50, train loss: 0.0013, train metric: 0.0356, valid metric: 0.0263
# Epoch 29/50, train loss: 0.0013, train metric: 0.0358, valid metric: 0.0280
# Epoch 30/50, train loss: 0.0013, train metric: 0.0352, valid metric: 0.0274
# Epoch 31/50, train loss: 0.0012, train metric: 0.0352, valid metric: 0.0281
# Epoch 32/50, train loss: 0.0012, train metric: 0.0354, valid metric: 0.0268
# Epoch 33/50, train loss: 0.0014, train metric: 0.0368, valid metric: 0.0307
# Epoch 34/50, train loss: 0.0013, train metric: 0.0350, valid metric: 0.0271
# Epoch 35/50, train loss: 0.0013, train metric: 0.0357, valid metric: 0.0295
# Epoch 36/50, train loss: 0.0012, train metric: 0.0351, valid metric: 0.0269
# Epoch 37/50, train loss: 0.0012, train metric: 0.0346, valid metric: 0.0271
# Epoch 38/50, train loss: 0.0012, train metric: 0.0347, valid metric: 0.0279
# Epoch 39/50, train loss: 0.0012, train metric: 0.0346, valid metric: 0.0277
# Epoch 40/50, train loss: 0.0012, train metric: 0.0348, valid metric: 0.0299
# Epoch 41/50, train loss: 0.0012, train metric: 0.0352, valid metric: 0.0296
# Epoch 42/50, train loss: 0.0012, train metric: 0.0351, valid metric: 0.0262
# Epoch 43/50, train loss: 0.0012, train metric: 0.0346, valid metric: 0.0268
# Epoch 44/50, train loss: 0.0012, train metric: 0.0350, valid metric: 0.0284
# Epoch 45/50, train loss: 0.0012, train metric: 0.0348, valid metric: 0.0278
# Epoch 46/50, train loss: 0.0013, train metric: 0.0359, valid metric: 0.0345
# Epoch 47/50, train loss: 0.0012, train metric: 0.0346, valid metric: 0.0319
# Epoch 48/50, train loss: 0.0012, train metric: 0.0353, valid metric: 0.0259
# Epoch 49/50, train loss: 0.0012, train metric: 0.0346, valid metric: 0.0263
# Epoch 50/50, train loss: 0.0013, train metric: 0.0353, valid metric: 0.0316
# 25926.249101758003

# %%
mulvar_model.eval()
Y_pred_valid = [mulvar_model(X.to(device)) for X, _ in multivar_valid_loader]
Y_pred_valid = torch.cat(Y_pred_valid, dim=0)
Y_valid = torch.cat([Y.to(device) for _, Y in multivar_valid_loader], dim=0)
for idx, name in enumerate(["bus", "rail"]):
    mae = (Y_pred_valid[:, idx] - Y_valid[:, idx]).abs().mean()
    print(name, int(mae * 1e6))
# Out:
# bus 35342
# rail 27883

# %%
class SimpleRnnModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.output = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        outputs, last_state = self.rnn(X)
        return self.output(outputs[:, -1])

class MultaskTimeSeriesDataset(TimeSeriesDataset):
    def __getitem__(self, idx):
        window, target = super().__getitem__(idx)
        return window, target[:2]

window_length = 56
multask_train_set = MultaskTimeSeriesDataset(mulvar_train, window_length)
multask_train_loader = DataLoader(multask_train_set, batch_size=32, shuffle=True)
multask_valid_set = MultaskTimeSeriesDataset(mulvar_valid, window_length)
multask_valid_loader = DataLoader(multask_valid_set, batch_size=32)
multask_test_set = MultaskTimeSeriesDataset(mulvar_test, window_length)
multask_test_loader = DataLoader(multask_test_set, batch_size=32)

torch.manual_seed(42)
multask_model = SimpleRnnModel(input_size=5, hidden_size=32, output_size=2)
multask_model = multask_model.to(device)
fit_and_evaluate(multask_model, multask_train_loader, multask_valid_loader, lr=0.03, n_epochs=50)
# Out:
# Epoch 1/50, train loss: 0.0514, train metric: 0.2416, valid metric: 0.1217
# Epoch 2/50, train loss: 0.0042, train metric: 0.0697, valid metric: 0.0371
# Epoch 3/50, train loss: 0.0023, train metric: 0.0485, valid metric: 0.0437
# Epoch 4/50, train loss: 0.0022, train metric: 0.0456, valid metric: 0.0308
# Epoch 5/50, train loss: 0.0021, train metric: 0.0451, valid metric: 0.0351
# Epoch 6/50, train loss: 0.0021, train metric: 0.0452, valid metric: 0.0363
# Epoch 7/50, train loss: 0.0020, train metric: 0.0438, valid metric: 0.0373
# Epoch 8/50, train loss: 0.0020, train metric: 0.0437, valid metric: 0.0352
# Epoch 9/50, train loss: 0.0019, train metric: 0.0423, valid metric: 0.0325
# Epoch 10/50, train loss: 0.0019, train metric: 0.0421, valid metric: 0.0362
# Epoch 11/50, train loss: 0.0019, train metric: 0.0418, valid metric: 0.0305
# Epoch 12/50, train loss: 0.0018, train metric: 0.0418, valid metric: 0.0359
# Epoch 13/50, train loss: 0.0018, train metric: 0.0409, valid metric: 0.0307
# Epoch 14/50, train loss: 0.0017, train metric: 0.0408, valid metric: 0.0296
# Epoch 15/50, train loss: 0.0017, train metric: 0.0404, valid metric: 0.0282
# Epoch 16/50, train loss: 0.0017, train metric: 0.0405, valid metric: 0.0338
# Epoch 17/50, train loss: 0.0017, train metric: 0.0396, valid metric: 0.0284
# Epoch 18/50, train loss: 0.0016, train metric: 0.0394, valid metric: 0.0290
# Epoch 19/50, train loss: 0.0016, train metric: 0.0397, valid metric: 0.0312
# Epoch 20/50, train loss: 0.0016, train metric: 0.0391, valid metric: 0.0264
# Epoch 21/50, train loss: 0.0016, train metric: 0.0390, valid metric: 0.0332
# Epoch 22/50, train loss: 0.0015, train metric: 0.0387, valid metric: 0.0370
# Epoch 23/50, train loss: 0.0015, train metric: 0.0384, valid metric: 0.0337
# Epoch 24/50, train loss: 0.0015, train metric: 0.0381, valid metric: 0.0311
# Epoch 25/50, train loss: 0.0015, train metric: 0.0375, valid metric: 0.0280
# Epoch 26/50, train loss: 0.0014, train metric: 0.0374, valid metric: 0.0306
# Epoch 27/50, train loss: 0.0015, train metric: 0.0379, valid metric: 0.0286
# Epoch 28/50, train loss: 0.0014, train metric: 0.0368, valid metric: 0.0287
# Epoch 29/50, train loss: 0.0014, train metric: 0.0374, valid metric: 0.0264
# Epoch 30/50, train loss: 0.0014, train metric: 0.0367, valid metric: 0.0263
# Epoch 31/50, train loss: 0.0014, train metric: 0.0367, valid metric: 0.0260
# Epoch 32/50, train loss: 0.0013, train metric: 0.0364, valid metric: 0.0262
# Epoch 33/50, train loss: 0.0014, train metric: 0.0361, valid metric: 0.0253
# Epoch 34/50, train loss: 0.0013, train metric: 0.0363, valid metric: 0.0245
# Epoch 35/50, train loss: 0.0013, train metric: 0.0362, valid metric: 0.0323
# Epoch 36/50, train loss: 0.0013, train metric: 0.0366, valid metric: 0.0271
# Epoch 37/50, train loss: 0.0013, train metric: 0.0357, valid metric: 0.0255
# Epoch 38/50, train loss: 0.0013, train metric: 0.0356, valid metric: 0.0271
# Epoch 39/50, train loss: 0.0013, train metric: 0.0354, valid metric: 0.0294
# Epoch 40/50, train loss: 0.0013, train metric: 0.0357, valid metric: 0.0252
# Epoch 41/50, train loss: 0.0013, train metric: 0.0357, valid metric: 0.0270
# Epoch 42/50, train loss: 0.0013, train metric: 0.0352, valid metric: 0.0292
# Epoch 43/50, train loss: 0.0013, train metric: 0.0351, valid metric: 0.0247
# Epoch 44/50, train loss: 0.0013, train metric: 0.0353, valid metric: 0.0257
# Epoch 45/50, train loss: 0.0012, train metric: 0.0348, valid metric: 0.0283
# Epoch 46/50, train loss: 0.0012, train metric: 0.0351, valid metric: 0.0322
# Epoch 47/50, train loss: 0.0013, train metric: 0.0356, valid metric: 0.0256
# Epoch 48/50, train loss: 0.0012, train metric: 0.0346, valid metric: 0.0278
# Epoch 49/50, train loss: 0.0012, train metric: 0.0349, valid metric: 0.0317
# Epoch 50/50, train loss: 0.0013, train metric: 0.0356, valid metric: 0.0276
# 24533.256888389587

# %%
multask_model.eval()
Y_pred_s = [mulvar_model(X.to(device)) for X, _ in multask_valid_loader]
Y_pred_s = torch.cat(Y_pred_s, dim=0)
Y_valid = torch.cat([Y.to(device) for _, Y in multask_valid_loader], dim=0)
for idx, name in enumerate(["bus", "rail"]):
    mae = (Y_pred_s[:, idx] - Y_valid[:, idx]).abs().mean()
    print(name, int(mae*1e6))
# Out:
# bus 35342
# rail 27883

# %% [markdown]
# **Forecasting Several Steps Ahead**

# %%
univar_model.eval()
n_steps = 14
with torch.no_grad():
    X = rail_valid[:window_length].unsqueeze(dim=0).to(device)
    for _ in range(n_steps):
        Y_pred = univar_model(X)
        X = torch.cat([X, Y_pred.unsqueeze(dim=0)], dim=1)
    Y_pred = X[0, -n_steps:, 0]

# %%
Y_pred_s = pd.Series(Y_pred.cpu() * 1e6, index=pd.date_range("2019-02-26", "2019-03-11"))

fig, ax = plt.subplots(figsize=(8, 3.5))
df["2019-02-01":"2019-03-11"]["rail"].plot(label="True", marker=".", ax=ax)
Y_pred_s.plot(label="Predictions", grid=True, marker="*", color="r", ax=ax)
ax.vlines("2019-02-25", 0, 1e6, color="k", linestyle="--", label="Today")
ax.set_ylim([200_000, 800_000])
plt.legend(loc="center left")
plt.show()

# %%
class ForecastAheadDataset(TimeSeriesDataset):
    def __len__(self):
        return len(self.series) - self.window_length - 14 + 1

    def __getitem__(self, idx):
        end = idx + self.window_length
        window = self.series[idx:end]
        target = self.series[end : end + 14, 0]
        return window, target

# %%
window_length = 56
ahead_train_set = ForecastAheadDataset(mulvar_train, window_length)
ahead_train_loader = DataLoader(ahead_train_set, batch_size=32, shuffle=True)
ahead_valid_set = ForecastAheadDataset(mulvar_valid, window_length)
ahead_valid_loader = DataLoader(ahead_valid_set, batch_size=32)
ahead_test_set = ForecastAheadDataset(mulvar_test, window_length)
ahead_test_loader = DataLoader(ahead_test_set, batch_size=32)

# %%
ahead_model = SimleRnnModel(input_size=5, hidden_size=32, output_size=14)
ahead_model = ahead_model.to(device)
fit_and_evaluate(ahead_model, ahead_train_loader, ahead_valid_loader, lr=0.05, n_epochs=50)
# Out:
# Epoch 1/50, train loss: 0.0666, train metric: 0.2881, valid metric: 0.1589
# Epoch 2/50, train loss: 0.0151, train metric: 0.1485, valid metric: 0.1249
# Epoch 3/50, train loss: 0.0129, train metric: 0.1350, valid metric: 0.1142
# Epoch 4/50, train loss: 0.0116, train metric: 0.1254, valid metric: 0.1074
# Epoch 5/50, train loss: 0.0106, train metric: 0.1156, valid metric: 0.0995
# Epoch 6/50, train loss: 0.0091, train metric: 0.1062, valid metric: 0.0915
# Epoch 7/50, train loss: 0.0081, train metric: 0.0978, valid metric: 0.0862
# Epoch 8/50, train loss: 0.0073, train metric: 0.0917, valid metric: 0.0820
# Epoch 9/50, train loss: 0.0069, train metric: 0.0875, valid metric: 0.0782
# Epoch 10/50, train loss: 0.0064, train metric: 0.0841, valid metric: 0.0749
# Epoch 11/50, train loss: 0.0061, train metric: 0.0807, valid metric: 0.0729
# Epoch 12/50, train loss: 0.0059, train metric: 0.0779, valid metric: 0.0701
# Epoch 13/50, train loss: 0.0056, train metric: 0.0754, valid metric: 0.0661
# Epoch 14/50, train loss: 0.0053, train metric: 0.0728, valid metric: 0.0650
# Epoch 15/50, train loss: 0.0054, train metric: 0.0706, valid metric: 0.0609
# Epoch 16/50, train loss: 0.0049, train metric: 0.0688, valid metric: 0.0608
# Epoch 17/50, train loss: 0.0047, train metric: 0.0663, valid metric: 0.0582
# Epoch 18/50, train loss: 0.0046, train metric: 0.0648, valid metric: 0.0542
# Epoch 19/50, train loss: 0.0046, train metric: 0.0633, valid metric: 0.0539
# Epoch 20/50, train loss: 0.0043, train metric: 0.0627, valid metric: 0.0525
# Epoch 21/50, train loss: 0.0042, train metric: 0.0611, valid metric: 0.0518
# Epoch 22/50, train loss: 0.0043, train metric: 0.0605, valid metric: 0.0518
# Epoch 23/50, train loss: 0.0041, train metric: 0.0598, valid metric: 0.0499
# Epoch 24/50, train loss: 0.0041, train metric: 0.0589, valid metric: 0.0473
# Epoch 25/50, train loss: 0.0040, train metric: 0.0583, valid metric: 0.0475
# Epoch 26/50, train loss: 0.0039, train metric: 0.0577, valid metric: 0.0474
# Epoch 27/50, train loss: 0.0039, train metric: 0.0570, valid metric: 0.0460
# Epoch 28/50, train loss: 0.0039, train metric: 0.0567, valid metric: 0.0469
# Epoch 29/50, train loss: 0.0038, train metric: 0.0561, valid metric: 0.0453
# Epoch 30/50, train loss: 0.0038, train metric: 0.0556, valid metric: 0.0434
# Epoch 31/50, train loss: 0.0038, train metric: 0.0555, valid metric: 0.0439
# Epoch 32/50, train loss: 0.0037, train metric: 0.0548, valid metric: 0.0434
# Epoch 33/50, train loss: 0.0037, train metric: 0.0546, valid metric: 0.0438
# Epoch 34/50, train loss: 0.0038, train metric: 0.0542, valid metric: 0.0413
# Epoch 35/50, train loss: 0.0036, train metric: 0.0542, valid metric: 0.0432
# Epoch 36/50, train loss: 0.0036, train metric: 0.0535, valid metric: 0.0422
# Epoch 37/50, train loss: 0.0037, train metric: 0.0533, valid metric: 0.0406
# Epoch 38/50, train loss: 0.0036, train metric: 0.0534, valid metric: 0.0404
# Epoch 39/50, train loss: 0.0036, train metric: 0.0526, valid metric: 0.0419
# Epoch 40/50, train loss: 0.0037, train metric: 0.0526, valid metric: 0.0389
# Epoch 41/50, train loss: 0.0036, train metric: 0.0524, valid metric: 0.0391
# Epoch 42/50, train loss: 0.0037, train metric: 0.0527, valid metric: 0.0395
# Epoch 43/50, train loss: 0.0037, train metric: 0.0520, valid metric: 0.0385
# Epoch 44/50, train loss: 0.0035, train metric: 0.0516, valid metric: 0.0392
# Epoch 45/50, train loss: 0.0035, train metric: 0.0517, valid metric: 0.0385
# Epoch 46/50, train loss: 0.0035, train metric: 0.0511, valid metric: 0.0382
# Epoch 47/50, train loss: 0.0035, train metric: 0.0511, valid metric: 0.0387
# Epoch 48/50, train loss: 0.0035, train metric: 0.0509, valid metric: 0.0395
# Epoch 49/50, train loss: 0.0035, train metric: 0.0506, valid metric: 0.0394
# Epoch 50/50, train loss: 0.0035, train metric: 0.0506, valid metric: 0.0391
# 38150.232285261154

# %%
ahead_model.eval()
with torch.no_grad():
    window = mulvar_valid[:window_length]  # shape [56, 5]
    X = window.unsqueeze(dim=0)            # shape [1, 56, 5]
    Y_pred = ahead_model(X.to(device))

# %%
Y_pred_s = pd.Series(Y_pred.permute(1,0)[:,0].cpu() * 1e6, index=pd.date_range("2019-02-26", "2019-03-11"))

fig, ax = plt.subplots(figsize=(8, 3.5))
df["2019-02-01":"2019-03-11"]["rail"].plot(label="True", marker=".", ax=ax)
Y_pred_s.plot(label="Predictions", grid=True, marker="*", color="r", ax=ax)
ax.vlines("2019-02-25", 0, 1e6, color="k", linestyle="--", label="Today")
ax.set_ylim([200_000, 800_000])
plt.legend(loc="center left")
plt.show()

# %% [markdown]
# **Forecasting Using a Sequence-to-Sequence Model**

# %%
class Seq2SeqDataset(ForecastAheadDataset):
    def __getitem__(self, idx):
        end = idx + self.window_length
        window = self.series[idx:end]
        target_period = self.series[idx + 1 : end + 14, 0]
        target = target_period.unfold(dimension=0, size=14, step=1)
        return window, target

# %%
window_length = 56
seq_train_set = Seq2SeqDataset(mulvar_train, window_length)
seq_train_loader = DataLoader(seq_train_set, batch_size=32, shuffle=True)
seq_valid_set = Seq2SeqDataset(mulvar_valid, window_length)
seq_valid_loader = DataLoader(seq_valid_set, batch_size=32)
seq_test_set = Seq2SeqDataset(mulvar_test, window_length)
seq_test_loader = DataLoader(seq_test_set, batch_size=32)

# %%
class Seq2SeqRNNModel(SimpleRnnModel):
    def forward(self, X):
        outputs, last_state = self.rnn(X)
        return self.output(outputs)

# %%
seq_model = Seq2SeqRNNModel(input_size=5, hidden_size=32, output_size=14)
seq_model = seq_model.to(device)
fit_and_evaluate(model=seq_model, train_loader=seq_train_loader, valid_loader=seq_valid_loader, lr=1.0, n_epochs=65, patience=5, factor=0.5)
# Out:
# Epoch 1/65, train loss: 0.0308, train metric: 0.1852, valid metric: 0.1139
# Epoch 2/65, train loss: 0.0055, train metric: 0.0725, valid metric: 0.0634
# Epoch 3/65, train loss: 0.0042, train metric: 0.0591, valid metric: 0.0728
# Epoch 4/65, train loss: 0.0039, train metric: 0.0560, valid metric: 0.0626
# Epoch 5/65, train loss: 0.0037, train metric: 0.0537, valid metric: 0.0488
# Epoch 6/65, train loss: 0.0037, train metric: 0.0533, valid metric: 0.0477
# Epoch 7/65, train loss: 0.0037, train metric: 0.0533, valid metric: 0.0470
# Epoch 8/65, train loss: 0.0036, train metric: 0.0526, valid metric: 0.0614
# Epoch 9/65, train loss: 0.0035, train metric: 0.0509, valid metric: 0.0573
# Epoch 10/65, train loss: 0.0034, train metric: 0.0497, valid metric: 0.0655
# Epoch 11/65, train loss: 0.0034, train metric: 0.0512, valid metric: 0.0496
# Epoch 12/65, train loss: 0.0034, train metric: 0.0491, valid metric: 0.0483
# Epoch 13/65, train loss: 0.0033, train metric: 0.0493, valid metric: 0.0488
# Epoch 14/65, train loss: 0.0033, train metric: 0.0480, valid metric: 0.0493
# Epoch 15/65, train loss: 0.0032, train metric: 0.0480, valid metric: 0.0496
# Epoch 16/65, train loss: 0.0032, train metric: 0.0478, valid metric: 0.0542
# Epoch 17/65, train loss: 0.0033, train metric: 0.0490, valid metric: 0.0491
# Epoch 18/65, train loss: 0.0032, train metric: 0.0479, valid metric: 0.0566
# Epoch 19/65, train loss: 0.0032, train metric: 0.0489, valid metric: 0.0509
# Epoch 20/65, train loss: 0.0033, train metric: 0.0475, valid metric: 0.0495
# Epoch 21/65, train loss: 0.0031, train metric: 0.0474, valid metric: 0.0508
# Epoch 22/65, train loss: 0.0031, train metric: 0.0473, valid metric: 0.0496
# Epoch 23/65, train loss: 0.0032, train metric: 0.0470, valid metric: 0.0492
# Epoch 24/65, train loss: 0.0032, train metric: 0.0470, valid metric: 0.0495
# Epoch 25/65, train loss: 0.0033, train metric: 0.0470, valid metric: 0.0505
# Epoch 26/65, train loss: 0.0031, train metric: 0.0474, valid metric: 0.0492
# Epoch 27/65, train loss: 0.0031, train metric: 0.0466, valid metric: 0.0495
# Epoch 28/65, train loss: 0.0031, train metric: 0.0468, valid metric: 0.0493
# Epoch 29/65, train loss: 0.0031, train metric: 0.0469, valid metric: 0.0501
# Epoch 30/65, train loss: 0.0031, train metric: 0.0471, valid metric: 0.0494
# Epoch 31/65, train loss: 0.0031, train metric: 0.0466, valid metric: 0.0494
# Epoch 32/65, train loss: 0.0031, train metric: 0.0465, valid metric: 0.0493
# Epoch 33/65, train loss: 0.0031, train metric: 0.0467, valid metric: 0.0492
# Epoch 34/65, train loss: 0.0031, train metric: 0.0465, valid metric: 0.0492
# Epoch 35/65, train loss: 0.0032, train metric: 0.0466, valid metric: 0.0495
# Epoch 36/65, train loss: 0.0031, train metric: 0.0468, valid metric: 0.0493
# Epoch 37/65, train loss: 0.0031, train metric: 0.0465, valid metric: 0.0493
# Epoch 38/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0492
# Epoch 39/65, train loss: 0.0031, train metric: 0.0465, valid metric: 0.0492
# Epoch 40/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0493
# Epoch 41/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0496
# Epoch 42/65, train loss: 0.0032, train metric: 0.0465, valid metric: 0.0494
# Epoch 43/65, train loss: 0.0031, train metric: 0.0466, valid metric: 0.0493
# Epoch 44/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0493
# Epoch 45/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0492
# Epoch 46/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0492
# Epoch 47/65, train loss: 0.0031, train metric: 0.0463, valid metric: 0.0494
# Epoch 48/65, train loss: 0.0031, train metric: 0.0465, valid metric: 0.0494
# Epoch 49/65, train loss: 0.0030, train metric: 0.0464, valid metric: 0.0493
# Epoch 50/65, train loss: 0.0030, train metric: 0.0464, valid metric: 0.0493
# Epoch 51/65, train loss: 0.0031, train metric: 0.0462, valid metric: 0.0493
# Epoch 52/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0493
# Epoch 53/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0492
# Epoch 54/65, train loss: 0.0031, train metric: 0.0465, valid metric: 0.0492
# Epoch 55/65, train loss: 0.0031, train metric: 0.0462, valid metric: 0.0494
# Epoch 56/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0493
# Epoch 57/65, train loss: 0.0031, train metric: 0.0463, valid metric: 0.0493
# Epoch 58/65, train loss: 0.0030, train metric: 0.0464, valid metric: 0.0493
# Epoch 59/65, train loss: 0.0030, train metric: 0.0464, valid metric: 0.0493
# Epoch 60/65, train loss: 0.0031, train metric: 0.0463, valid metric: 0.0493
# Epoch 61/65, train loss: 0.0031, train metric: 0.0463, valid metric: 0.0493
# Epoch 62/65, train loss: 0.0031, train metric: 0.0464, valid metric: 0.0493
# Epoch 63/65, train loss: 0.0031, train metric: 0.0463, valid metric: 0.0493
# Epoch 64/65, train loss: 0.0031, train metric: 0.0463, valid metric: 0.0493
# Epoch 65/65, train loss: 0.0032, train metric: 0.0464, valid metric: 0.0493
# 47014.154493808746

# %%
seq_model.eval()
with torch.no_grad():
    some_window = mulvar_valid[:window_length]
    X = some_window.unsqueeze(dim=0)
    Y_preds = seq_model(X.to(device))
    Y_pred = Y_preds[:, -1]

# %%
with torch.no_grad():
    X =mulvar_valid.unsqueeze(dim=0).to(device)
    Y_preds_valid = seq_model(X).cpu()

for ahead in range(1, 14 + 1):
    y_preds = Y_preds_valid[0, window_length : -ahead, ahead - 1]
    y_true = rail_valid[window_length + ahead:, 0]
    mae = (y_preds - y_true).abs().mean() * 1e6
    print(f"MAE for +{ahead}:\t{mae:,.0f}")
# Out:
# MAE for +1:	24,058
# MAE for +2:	34,005
# MAE for +3:	37,123
# MAE for +4:	37,709
# MAE for +5:	38,727
# MAE for +6:	38,820
# MAE for +7:	38,417
# MAE for +8:	38,324
# MAE for +9:	39,754
# MAE for +10:	37,590
# MAE for +11:	37,539
# MAE for +12:	37,159
# MAE for +13:	36,621
# MAE for +14:	33,697

# %%
torch.manual_seed(42)
with torch.no_grad():
    X = torch.randn(10, 56, 32)
    conv1d = nn.Conv1d(32, 14, kernel_size=1)
    linear = nn.Linear(32, 14)
    linear.weight.data = conv1d.weight.squeeze(dim=2)
    linear.bias.data = conv1d.bias
    result1 = conv1d(X.permute(0, 2, 1)).permute(0, 2, 1)
    result2 = linear(X)

torch.allclose(result1, result2, atol=1e-7)
# Out:
# True

# %% [markdown]
# **Deep RNNs with Layer Norm**

# %%
class SimpleRnnWithLN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.memmory_cell = nn.Sequential(
            nn.Linear(input_size + hidden_size, hidden_size),
            nn.LayerNorm(hidden_size),
            nn.Tanh()
        )
        self.output = nn.Linear(hidden_size, output_size)
    def forward(self, X):
        batch_size, window_length, dimensionality = X.shape
        X_time_first = X.transpose(0, 1)
        H = torch.zeros(batch_size, self.hidden_size, device=X.device)
        for X_t in X_time_first:
            XH = torch.cat((X_t, H), dim=1)
            H = self.memmory_cell(XH)
        return self.output(H)

# %%
rnn_with_layer_norm = SimpleRnnWithLN(input_size=5, hidden_size=32, output_size=14)
rnn_with_layer_norm = rnn_with_layer_norm.to(device)
fit_and_evaluate(rnn_with_layer_norm, ahead_train_loader, ahead_valid_loader, lr=0.05, n_epochs=2)
# Out:
# Epoch 1/2, train loss: 0.0948, train metric: 0.3336, valid metric: 0.1777
# Epoch 2/2, train loss: 0.0174, train metric: 0.1528, valid metric: 0.1288
# 128820.35970687866

# %% [markdown]
# **LSTMs**

# %% [markdown]
# ![hmls_1312.png](data:image/png;base64,...)

# %% [markdown]
# Сначала текущий входной вектор x ( t ) и предыдущее кратковременное состояние h ( t –1) подаются на четыре различных полносвязных слоя. Каждый из них выполняет различную функцию:
#
# Основной слой — это тот, который выводит g ( t ) . Его обычная роль заключается в анализе текущих входных данных x ( t ) и предыдущего (краткосрочного) состояния h ( t –1) . В простой ячейке RNN нет ничего, кроме этого слоя, и его выход напрямую поступает в y ( t ) и h ( t ) . Но в ячейке LSTM выход этого слоя не поступает напрямую; вместо этого его наиболее важные части хранятся в долгосрочном состоянии (а остальное отбрасывается).
#
# Три других слояявляются контроллерами вентилей . Поскольку они используют логистическую функцию активации, выходы находятся в диапазоне от 0 до 1. Как видите, выходы контроллеров вентилей используются для поэлементного умножения: если на выходе нули, то вентиль закрывается, а если единицы, то он открывается. А именно:
#
# Вентиль забывания (управляемый f ( t ) ) контролирует, какие части долгосрочного состояния следует стереть.
#
# Входной вентиль (управляемый i ( t ) ) контролирует, какие части g ( t ) следует добавить к долгосрочному состоянию.
#
# Наконец, выходной вентиль (управляемый o ( t ) ) контролирует, какие части долгосрочного состояния должны быть считаны и выведены на данном этапе времени, как в h ( t ) , так и в y ( t )

# %% [markdown]
# ![{4CD0D3C0-6070-433F-8722-0841902F5D8F}.png](data:image/png;base64,...)

# %% [markdown]
# ![{3DD872B9-F83C-44BF-98ED-CF252ECB64DA}.png](data:image/png;base64,...)

# %%
class LstmModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.memmory_cell = nn.LSTMCell(input_size, hidden_size)
        self.output = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        batch_size, window_length, dimensionality = X.shape
        X_time_first = X.transpose(0, 1)
        H = torch.zeros(batch_size, self.hidden_size, device=X.device)
        C = torch.zeros(batch_size, self.hidden_size, device=X.device)
        for X_t in X_time_first:
            H, C = self.memmory_cell(X_t, (H, C))
        return self.output(H)

# %%
torch.manual_seed(42)
lstm_model = LstmModel(input_size=5, hidden_size=32, output_size=14)
lstm_model = lstm_model.to(device)
fit_and_evaluate(lstm_model, ahead_train_loader, ahead_valid_loader, lr=0.05, n_epochs=2)
# Out:
# Epoch 1/2, train loss: 0.1036, train metric: 0.3962, valid metric: 0.1534
# Epoch 2/2, train loss: 0.0175, train metric: 0.1480, valid metric: 0.1414
# 141420.9008216858

# %% [markdown]
# **GRUs**

# %% [markdown]
# ![hmls_1313 (1).png](data:image/png;base64,...)

# %% [markdown]
# ![{E9162A50-FA84-4172-9032-29D8D26902A0}.png](data:image/png;base64,...)

# %%
class GruModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.memory_cell = nn.GRUCell(input_size, hidden_size)
        self.output = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        batch_size, window_length, dimensionality = X.shape
        X_time_first = X.transpose(0, 1)
        H = torch.zeros(batch_size, self.hidden_size, device=X.device)
        for X_t in X_time_first:
            H = self.memory_cell(X_t, H)
        return self.output(H)

# %%
torch.manual_seed(42)
gru_model = GruModel(input_size=5, hidden_size=32, output_size=14)
gru_model = gru_model.to(device)
fit_and_evaluate(gru_model, ahead_train_loader, ahead_valid_loader,
                 lr=0.05, n_epochs=2)
# Out:
# Epoch 1/2, train loss: 0.0785, train metric: 0.3166, valid metric: 0.1443
# Epoch 2/2, train loss: 0.0170, train metric: 0.1571, valid metric: 0.1359
# 135890.6477689743

# %% [markdown]
# **Using One-Dimensional Convolutional Layers to Process Sequences**

# %%
class DownsamplingModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.conv = nn.Conv1d(input_size, hidden_size, kernel_size=4, stride=2)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.linear = nn.Linear(hidden_size, output_size)


    def forward(self, X):
        Z = X.permute(0, 2, 1)
        Z = self.conv(Z)
        Z = Z.permute(0, 2, 1)
        Z = torch.relu(Z)
        Z, _states = self.gru(Z)
        return self.linear(Z)

# %%
torch.manual_seed(42)
dseq_model = DownsamplingModel(input_size=1, hidden_size=32, output_size=14)
dseq_model = dseq_model.to(device)

# %%
class DownsampledDataset(Seq2SeqDataset):
    def __getitem__(self, idx):
        window, target = super().__getitem__(idx)
        return window, target[3::2]  # crop the first 3 targets and downsample

window_length = 112
dseq_train_set = DownsampledDataset(rail_train, window_length)
dseq_train_loader = DataLoader(dseq_train_set, batch_size=32, shuffle=True)
dseq_valid_set = DownsampledDataset(rail_valid, window_length)
dseq_valid_loader = DataLoader(dseq_valid_set, batch_size=32)
dseq_test_set = DownsampledDataset(rail_test, window_length)
dseq_test_loader = DataLoader(dseq_test_set, batch_size=32)

# %%
torch.manual_seed(42)
dseq_model = DownsamplingModel(input_size=1, hidden_size=32, output_size=14)
dseq_model = dseq_model.to(device)
fit_and_evaluate(dseq_model, dseq_train_loader, dseq_valid_loader,
                 lr=0.2, n_epochs=2)
# Out:
# Epoch 1/2, train loss: 0.0510, train metric: 0.2497, valid metric: 0.1676
# Epoch 2/2, train loss: 0.0169, train metric: 0.1581, valid metric: 0.1486
# 148577.85403728485

# %% [markdown]
# **WaveNet**

# %% [markdown]
# ![hmls_1314 (1).png](data:image/png;base64,...)

# %%
import torch.nn.functional as F

class CausalConv1d(nn.Conv1d):
    def forward(self, X):
        padding = (self.kernel_size[0] - 1) * self.dilation[0]
        X = F.pad(X, (padding, 0))
        return super().forward(X)

# %%
class WavenetModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        layers = []
        for dilation in (1, 2, 4, 8) * 2:
            conv = CausalConv1d(input_size, hidden_size, kernel_size=2,
                                dilation=dilation)
            layers += [conv, nn.ReLU()]
            input_size = hidden_size
        self.convs = nn.Sequential(*layers)
        self.output = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        Z = X.permute(0, 2, 1)
        Z = self.convs(Z)
        Z = Z.permute(0, 2, 1)
        return self.output(Z)

torch.manual_seed(42)
wavenet_model = WavenetModel(input_size=5, hidden_size=32, output_size=14)
wavenet_model = wavenet_model.to(device)

# %%
fit_and_evaluate(wavenet_model, seq_train_loader, seq_valid_loader,
                 lr=0.1, n_epochs=150)
# Out:
# Epoch 1/150, train loss: 0.0810, train metric: 0.3227, valid metric: 0.1557
# Epoch 2/150, train loss: 0.0171, train metric: 0.1602, valid metric: 0.1476
# Epoch 3/150, train loss: 0.0163, train metric: 0.1564, valid metric: 0.1473
# Epoch 4/150, train loss: 0.0161, train metric: 0.1586, valid metric: 0.1458
# Epoch 5/150, train loss: 0.0161, train metric: 0.1577, valid metric: 0.1469
# Epoch 6/150, train loss: 0.0161, train metric: 0.1577, valid metric: 0.1467
# Epoch 7/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 8/150, train loss: 0.0162, train metric: 0.1584, valid metric: 0.1462
# Epoch 9/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1470
# Epoch 10/150, train loss: 0.0161, train metric: 0.1576, valid metric: 0.1472
# Epoch 11/150, train loss: 0.0162, train metric: 0.1585, valid metric: 0.1460
# Epoch 12/150, train loss: 0.0162, train metric: 0.1572, valid metric: 0.1474
# Epoch 13/150, train loss: 0.0161, train metric: 0.1582, valid metric: 0.1461
# Epoch 14/150, train loss: 0.0162, train metric: 0.1577, valid metric: 0.1465
# Epoch 15/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1470
# Epoch 16/150, train loss: 0.0161, train metric: 0.1581, valid metric: 0.1468
# Epoch 17/150, train loss: 0.0161, train metric: 0.1576, valid metric: 0.1469
# Epoch 18/150, train loss: 0.0162, train metric: 0.1577, valid metric: 0.1467
# Epoch 19/150, train loss: 0.0163, train metric: 0.1587, valid metric: 0.1461
# Epoch 20/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1468
# Epoch 21/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1468
# Epoch 22/150, train loss: 0.0162, train metric: 0.1581, valid metric: 0.1465
# Epoch 23/150, train loss: 0.0161, train metric: 0.1577, valid metric: 0.1470
# Epoch 24/150, train loss: 0.0162, train metric: 0.1575, valid metric: 0.1474
# Epoch 25/150, train loss: 0.0161, train metric: 0.1583, valid metric: 0.1463
# Epoch 26/150, train loss: 0.0163, train metric: 0.1573, valid metric: 0.1464
# Epoch 27/150, train loss: 0.0162, train metric: 0.1577, valid metric: 0.1467
# Epoch 28/150, train loss: 0.0161, train metric: 0.1580, valid metric: 0.1469
# Epoch 29/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 30/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 31/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 32/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1468
# Epoch 33/150, train loss: 0.0161, train metric: 0.1580, valid metric: 0.1468
# Epoch 34/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1467
# Epoch 35/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 36/150, train loss: 0.0162, train metric: 0.1580, valid metric: 0.1468
# Epoch 37/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1468
# Epoch 38/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1468
# Epoch 39/150, train loss: 0.0161, train metric: 0.1580, valid metric: 0.1469
# Epoch 40/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 41/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1467
# Epoch 42/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 43/150, train loss: 0.0161, train metric: 0.1577, valid metric: 0.1466
# Epoch 44/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 45/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1468
# Epoch 46/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 47/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1467
# Epoch 48/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1467
# Epoch 49/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 50/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 51/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 52/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 53/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 54/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 55/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 56/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 57/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1467
# Epoch 58/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1467
# Epoch 59/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 60/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 61/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 62/150, train loss: 0.0162, train metric: 0.1578, valid metric: 0.1467
# Epoch 63/150, train loss: 0.0161, train metric: 0.1578, valid metric: 0.1467
# Epoch 64/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 65/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 66/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 67/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 68/150, train loss: 0.0160, train metric: 0.1579, valid metric: 0.1467
# Epoch 69/150, train loss: 0.0160, train metric: 0.1579, valid metric: 0.1467
# Epoch 70/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 71/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 72/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 73/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 74/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 75/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 76/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 77/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 78/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 79/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 80/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 81/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 82/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 83/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 84/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 85/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 86/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 87/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 88/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 89/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 90/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 91/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 92/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 93/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 94/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 95/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 96/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 97/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 98/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 99/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 100/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 101/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 102/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 103/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 104/150, train loss: 0.0163, train metric: 0.1579, valid metric: 0.1467
# Epoch 105/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 106/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 107/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 108/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 109/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 110/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 111/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 112/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 113/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 114/150, train loss: 0.0163, train metric: 0.1579, valid metric: 0.1467
# Epoch 115/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 116/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 117/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 118/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 119/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 120/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 121/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 122/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 123/150, train loss: 0.0163, train metric: 0.1579, valid metric: 0.1467
# Epoch 124/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 125/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 126/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 127/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 128/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 129/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 130/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 131/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 132/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 133/150, train loss: 0.0163, train metric: 0.1579, valid metric: 0.1467
# Epoch 134/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 135/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 136/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 137/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 138/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 139/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 140/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 141/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 142/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 143/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 144/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 145/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 146/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 147/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 148/150, train loss: 0.0162, train metric: 0.1579, valid metric: 0.1467
# Epoch 149/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# Epoch 150/150, train loss: 0.0161, train metric: 0.1579, valid metric: 0.1467
# 145769.29807662964
